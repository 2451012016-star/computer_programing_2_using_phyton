# %% [markdown]
# *   NAMA : DANU GALANG SAPUTRA
#
# *   NPM : 2451012016
# *   PRAKTIKUM KALKULATOR PAJAK

# %%
from TRANSAKSI.diskon import hitung_diskon as hitung_diskon
from TRANSAKSI.pajak import hitung_ppn as hitung_ppn

harga_awal = 1000000
diskon_persen = 10

potongan = hitung_diskon(harga_awal, diskon_persen)
harga_setelah_diskon = harga_awal - potongan

ppn = hitung_ppn(harga_setelah_diskon)
total_bayar = harga_setelah_diskon + ppn

print(" harga awal :", harga_awal)
print("potongan diskon  :", potongan)
print(" harga setelah diskon :", harga_setelah_diskon)
print(" besaran ppn (11%) :", ppn)
print("total bayar :", total_bayar)
# Out:
#  harga awal : 1000000
# potongan diskon  : 100000.0
#  harga setelah diskon : 900000.0
#  besaran ppn (11%) : 99000.0
# total bayar : 999000.0
