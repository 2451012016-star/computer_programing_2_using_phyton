# %% [markdown]
# *   NAMA : DANU GALANG SAPUTRA
# *   NPM : 2451012016

# %%
import requests

nama = input("Masukkan nama: ")

url = f"https://api.genderize.io?name={nama}"
response = requests.get(url)
data = response.json()
print(f"Nama         : {data['name']}")
print(f"Jenis kelamin: {data['gender']}")
print(f"probabilitas : {data['probability']}")
# Out:
# Masukkan nama: Galang
# Nama         : Galang
# Jenis kelamin: male
# probabilitas : 0.88
